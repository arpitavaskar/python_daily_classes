# %%
print("hello world"*3)
# Out:
# hello worldhello worldhello world

# %%
print("python programming language\n"*5)
# Out:
# python programming language
# python programming language
# python programming language
# python programming language
# python programming language

# %%
print(100/3)
# Out:
# 33.333333333333336

# %%
print("arpita vaskar\n"*10000)
# Out:
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# arpita vaskar
# ...

# %%
print("hindi=18\nic=24\ncp=29\ndbms=18\nenglish=18\naccount=19")
# Out:
# hindi=18
# ic=24
# cp=29
# dbms=18
# english=18
# account=19

# %%
NA_21_ME="chikodi"

# %%
name="college"
per=67.34
print(name,per)
# Out:
# college 67.34

# %%
#My name is Arpita, i'm studying  in BKC College

College = "BKC COLLEGE"
Name = " arpita"

print("my name is",Name,"I'm studying in",College)
# Out:
# my name is  arpita I'm studying in BKC COLLEGE

# %%
Name = "CLE PU COLLEGE"
Per = 70.78
Year = 2024

print("I have completed pu in",Name,"in the year ",Year,", i got percentage is",Per)
# Out:
# I have completed pu in CLE PU COLLEGE in the year  2024 , i got percentage is 70.78

# %%
text = "good night"
address = "I'M From ckd"

print("Hello",text,"how are you",i'm fine,"where are from",address,"so nice")
# Out:
#   File "/tmp/ipython-input-2718448723.py", line 4
#     print("Hello",text,"how are you",i'm fine,"where are from",address,"so nice")
#                                       ^
# SyntaxError: unterminated string literal (detected at line 4)
